# %%
import socket
mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect( ('data.pr4e.org', 80) )

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if (len(data) < 1):
        break
    print(data.decode(),end='')
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Mon, 22 Jul 2024 04:07:27 GMT
# Server: Apache/2.4.52 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if (len(data) < 1):
        break
    print(data.decode(),end='')
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Mon, 22 Jul 2024 04:07:52 GMT
# Server: Apache/2.4.52 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, 'html.parser')

# Retrieve all of the anchor tags
tags = soup('a')
for tag in tags:
    print(tag.get('href', None))
# Out:
# Enter - https://search.naver.com/search.naver?ssc=tab.news.all&where=news&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# #lnb
# #content
# https://www.naver.com
# #
# #
# ?ssc=tab.nx.all&where=nexearch&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.news.all&where=news&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.blog.all&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.cafe.all&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.image.all&where=image&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.kin.kqna&where=kin&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.influencer.chl&where=influencer&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.video.all&where=video&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# https://search.shopping.naver.com/search/all?where=all&frm=NVSCTAB&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.shortents.all&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# https://dict.naver.com/dict.search?query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC&from=tsearch
# https://map.naver.com/v5/search/%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# https://search.shopping.naver.com/book/search?query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# https://terms.naver.com/search.naver?query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# https://academic.naver.com/search.naver?field=0&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# #
# #
# #
# ?ssc=tab.nx.all&where=nexearch&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.news.all&where=news&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.blog.all&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.cafe.all&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.image.all&where=image&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.kin.kqna&where=kin&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.influencer.chl&where=influencer&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.video.all&where=video&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# https://search.shopping.naver.com/search/all?where=all&frm=NVSCTAB&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# ?ssc=tab.shortents.all&sm=tab_jum&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# https://dict.naver.com/dict.search?query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC&from=tsearch
# https://map.naver.com/v5/search/%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# https://search.shopping.naver.com/book/search?query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# https://terms.naver.com/search.naver?query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# https://academic.naver.com/search.naver?field=0&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC
# #
# #
# #
# #
# #
# javascript:;
# javascript:;
# #
# #
# #
# javascript:;
# javascript:;
# javascript:;
# #
# #
# #
# #
# #
# #
# #
# #
# #
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# #
# #
# #
# #
# #
# #
# #
# #
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# ?mynews=0&nso_open=1&office_category=0&office_type=0&query=%ED%94%84%EB%A1%9C%EC%95%BC%EA%B5%AC&service_area=0&sm=tab_opt&ssc=tab.news.all
# None
# javascript:;
# javascript:;
# https://help.naver.com/alias/news/news_43.naver
# https://news.naver.com/main/static/channelPromotion.html
# https://media.naver.com/press/001
# https://media.naver.com/press/001
# https://m.sports.naver.com/kbaseball/article/001/0015341557
# #
# https://keep.naver.com
# https://www.yna.co.kr/view/AKR20250421048700007?input=1195m
# https://www.yna.co.kr/view/AKR20250421048700007?input=1195m
