# %%
# %pip install requests
# %pip install bs4
# Out:
# ...
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# ...
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# ...
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# ...
#
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------------------------------- 0/5 [urllib3]
#    -------- ------------------------------- 1/5 [idna]
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://brand.naver.com/jeongilpumblackgoat/products/9812882784?site_preference=device&NaPm=ct%3Dme6p1zot%7Cci%3Dshopn%7Ctr%3Dnshfum%7Chk%3D4492ff87ded8a3b0516371280ed6ac7d5ad4c98e%7Ctrx%3Dundefined#REVIEW'
header = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36'}

response = requests.get(url, header= header)
soup = BeautifulSoup(response.text, 'lxml')
review = soup.select('')
print(review[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 url = 'https://brand.naver.com/jeongilpumblackgoat/products/9812882784?site_preference=device&NaPm=ct%3Dme6p1zot%7Cci%3Dshopn%7Ctr%3Dnshfum%7Chk%3D4492ff87ded8a3b0516371280ed6ac7d5ad4c98e%7Ctrx%3Dundefined#REVIEW'
#       2 header = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36'}
# ----> 4 response = requests.get(url, header= header)
#       5 soup = BeautifulSoup(response.text, 'lxml')
#       6 review = soup.select('')
#
# File c:\Users\thswj\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
# ...

# %%
# iframe
url = 'https://brand.naver.com/jeongilpumblackgoat/products/9812882784?site_preference=device&NaPm=ct%3Dme6p1zot%7Cci%3Dshopn%7Ctr%3Dnshfum%7Chk%3D4492ff87ded8a3b0516371280ed6ac7d5ad4c98e%7Ctrx%3Dundefined#REVIEW'
header = {'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36'}

response = requests.get(url, header= header)
soup = BeautifulSoup(response.text, 'lxml')
review = soup.select('')
print(review[3].text)

for i in review:
    print(i.text.strip())
# Out:
# https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyNTAxMTNfNDEg%2FMDAxNzM2NzM4NDQ1MTgz._ctDgmvaGRw8dUK5h1Ain7Mk2XR_dt2c7UQ5VEJIwAUg.0z8_DlPjxc3JNn8YARgGm_KQctpQVuSwdU0JtHlwdekg.JPEG%2F0003295767_012_20250113112309191.jpg&type=a340
# ...
